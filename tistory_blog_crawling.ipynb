# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from bs4 import BeautifulSoup

# %%
# !pip install pandas openpyxl beautifulsoup4 requests

# %%
import sys

# Google Colab 환경에서 실행 중인지 확인
if 'google.colab' in sys.modules:
    # debconf를 Noninteractive 모드로 설정
    # !echo 'debconf debconf/frontend select Noninteractive' | debconf-set-selections

    # fonts-nanum 패키지를 설치
    # !sudo apt-get -qq -y install fonts-nanum

    # Matplotlib의 폰트 매니저 가져오기
    import matplotlib.font_manager as fm

    # 나눔 폰트의 시스템 경로 찾기
    font_files = fm.findSystemFonts(fontpaths=['/usr/share/fonts/truetype/nanum'])

    # 찾은 각 나눔 폰트를 Matplotlib 폰트 매니저에 추가
    for fpath in font_files:
        fm.fontManager.addfont(fpath)
# Out:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 124565 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...

# %%
# !pip install requests beautifulsoup4 pandas matplotlib konlpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 23.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.9/493.9 kB 18.9 MB/s eta 0:00:00
# ...

# %%
# Import matplotlib and matplotlib.pyplot
import matplotlib
import matplotlib.pyplot as plt

# Configure the font family to 'NanumGothic' and then to 'NanumBarunGothic'
plt.rcParams['font.family'] = 'NanumGothic'    #사용 방법1
plt.rc('font', family='NanumBarunGothic', size=11) #사용 방법2
print(plt.rcParams['font.family'], plt.rcParams['font.size'])   # 폰트확인
# Out:
# ['NanumBarunGothic'] 11.0

# %% [markdown]
# # content crawling

# %% [markdown]
# - 미숙아 연하 곤란

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# Function to extract content from a URL
def extract_content(url):
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()  # Check for HTTP request errors
        soup = BeautifulSoup(response.text, 'html.parser')
        # Extract the main text content (customize based on the website's structure)
        content = soup.get_text(separator="\n", strip=True)
        return content[:1000]  # Limit to the first 1000 characters for preview
    except Exception as e:
        return f"Error: {str(e)}"

# Main script
def main(input_file, output_file):
    # Load the Excel file
    df = pd.read_excel(input_file)

    # Check if 'link' column exists
    if 'link' not in df.columns:
        print("Error: 'link' column not found in the input file.")
        return

    # Extract content for each link
    df['content'] = df['link'].apply(extract_content)

    # Save the updated DataFrame to a new Excel file
    df.to_excel(output_file, index=False)
    print(f"Content extracted and saved to {output_file}")

# Specify the input and output file paths
if __name__ == "__main__":
    input_file = "/content/drive/MyDrive/tistoryblog/미숙아 연하 곤란_tistoryblog.xlsx"  # Replace with your input file path
    output_file = "/content/drive/MyDrive/tistoryblog/tistory_content/미숙아 연하 곤란_with_content.xlsx"  # Replace with your desired output file path

    main(input_file, output_file)
# Out:
# Content extracted and saved to /content/drive/MyDrive/tistoryblog/tistory_content/미숙아 연하 곤란_with_content.xlsx

# %% [markdown]
# - 미숙아 삼킴 문제

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# Function to extract content from a URL
def extract_content(url):
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()  # Check for HTTP request errors
        soup = BeautifulSoup(response.text, 'html.parser')
        # Extract the main text content (customize based on the website's structure)
        content = soup.get_text(separator="\n", strip=True)
        return content[:1000]  # Limit to the first 1000 characters for preview
    except Exception as e:
        return f"Error: {str(e)}"

# Main script
def main(input_file, output_file):
    # Load the Excel file
    df = pd.read_excel(input_file)

    # Check if 'link' column exists
    if 'link' not in df.columns:
        print("Error: 'link' column not found in the input file.")
        return

    # Extract content for each link
    df['content'] = df['link'].apply(extract_content)

    # Save the updated DataFrame to a new Excel file
    df.to_excel(output_file, index=False)
    print(f"Content extracted and saved to {output_file}")

# Specify the input and output file paths
if __name__ == "__main__":
    input_file = "/content/drive/MyDrive/tistoryblog/미숙아 삼킴 문제_tistoryblog.xlsx"  # Replace with your input file path
    output_file = "/content/drive/MyDrive/tistoryblog/tistory_content/미숙아 삼킴 문제_with_content.xlsx"  # Replace with your desired output file path

    main(input_file, output_file)
# Out:
# Content extracted and saved to /content/drive/MyDrive/tistoryblog/tistory_content/미숙아 삼킴 문제_with_content.xlsx

# %% [markdown]
# - 미숙아 모유수유 문제

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# Function to extract content from a URL
def extract_content(url):
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()  # Check for HTTP request errors
        soup = BeautifulSoup(response.text, 'html.parser')
        # Extract the main text content (customize based on the website's structure)
        content = soup.get_text(separator="\n", strip=True)
        return content[:1000]  # Limit to the first 1000 characters for preview
    except Exception as e:
        return f"Error: {str(e)}"

# Main script
def main(input_file, output_file):
    # Load the Excel file
    df = pd.read_excel(input_file)

    # Check if 'link' column exists
    if 'link' not in df.columns:
        print("Error: 'link' column not found in the input file.")
        return

    # Extract content for each link
    df['content'] = df['link'].apply(extract_content)

    # Save the updated DataFrame to a new Excel file
    df.to_excel(output_file, index=False)
    print(f"Content extracted and saved to {output_file}")

# Specify the input and output file paths
if __name__ == "__main__":
    input_file = "/content/drive/MyDrive/tistoryblog/미숙아 모유수유 문제_tistoryblog.xlsx"  # Replace with your input file path
    output_file = "/content/drive/MyDrive/tistoryblog/tistory_content/미숙아 모유수유 문제_with_content.xlsx"  # Replace with your desired output file path

    main(input_file, output_file)
# Out:
# Content extracted and saved to /content/drive/MyDrive/tistoryblog/tistory_content/미숙아 모유수유 문제_with_content.xlsx

# %% [markdown]
# - 미숙아 빨기 문제

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# Function to extract content from a URL
def extract_content(url):
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()  # Check for HTTP request errors
        soup = BeautifulSoup(response.text, 'html.parser')
        # Extract the main text content (customize based on the website's structure)
        content = soup.get_text(separator="\n", strip=True)
        return content[:1000]  # Limit to the first 1000 characters for preview
    except Exception as e:
        return f"Error: {str(e)}"

# Main script
def main(input_file, output_file):
    # Load the Excel file
    df = pd.read_excel(input_file)

    # Check if 'link' column exists
    if 'link' not in df.columns:
        print("Error: 'link' column not found in the input file.")
        return

    # Extract content for each link
    df['content'] = df['link'].apply(extract_content)

    # Save the updated DataFrame to a new Excel file
    df.to_excel(output_file, index=False)
    print(f"Content extracted and saved to {output_file}")

# Specify the input and output file paths
if __name__ == "__main__":
    input_file = "/content/drive/MyDrive/tistoryblog/미숙아 빨기 문제_tistoryblog.xlsx"  # Replace with your input file path
    output_file = "/content/drive/MyDrive/tistoryblog/tistory_content/미숙아 빨기 문제_with_content.xlsx"  # Replace with your desired output file path

    main(input_file, output_file)
# Out:
# Content extracted and saved to /content/drive/MyDrive/tistoryblog/tistory_content/미숙아 빨기 문제_with_content.xlsx

# %% [markdown]
# - 미숙아 수유 어려움

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# Function to extract content from a URL
def extract_content(url):
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()  # Check for HTTP request errors
        soup = BeautifulSoup(response.text, 'html.parser')
        # Extract the main text content (customize based on the website's structure)
        content = soup.get_text(separator="\n", strip=True)
        return content[:1000]  # Limit to the first 1000 characters for preview
    except Exception as e:
        return f"Error: {str(e)}"

# Main script
def main(input_file, output_file):
    # Load the Excel file
    df = pd.read_excel(input_file)

    # Check if 'link' column exists
    if 'link' not in df.columns:
        print("Error: 'link' column not found in the input file.")
        return

    # Extract content for each link
    df['content'] = df['link'].apply(extract_content)

    # Save the updated DataFrame to a new Excel file
    df.to_excel(output_file, index=False)
    print(f"Content extracted and saved to {output_file}")

# Specify the input and output file paths
if __name__ == "__main__":
    input_file = "/content/drive/MyDrive/tistoryblog/미숙아 수유 어려움_tistoryblog.xlsx"  # Replace with your input file path
    output_file = "/content/drive/MyDrive/tistoryblog/tistory_content/미숙아 수유 어려움_with_content.xlsx"  # Replace with your desired output file path

    main(input_file, output_file)
# Out:
# Content extracted and saved to /content/drive/MyDrive/tistoryblog/tistory_content/미숙아 수유 어려움_with_content.xlsx

# %% [markdown]
# - csv 로 변경

# %%
import os
import pandas as pd

# 엑셀 파일들이 있는 폴더 경로
input_folder_path = "/content/drive/MyDrive/tistoryblog/tistory_content/"
output_folder_path = "/content/drive/MyDrive/tistoryblog/tistory_csv파일/"

# 출력 폴더가 없으면 생성
os.makedirs(output_folder_path, exist_ok=True)

# 폴더 내 엑셀 파일 목록 가져오기
excel_files = [file for file in os.listdir(input_folder_path) if file.endswith(('.xlsx', '.xls'))]

# 변환 작업
for file in excel_files:
    try:
        # 파일 경로 설정
        input_file_path = os.path.join(input_folder_path, file)
        output_file_name = os.path.splitext(file)[0] + ".csv"
        output_file_path = os.path.join(output_folder_path, output_file_name)

        # 엑셀 파일 읽기
        data = pd.read_excel(input_file_path, engine='openpyxl')

        # CSV 파일로 저장 (UTF-8-sig 인코딩)
        data.to_csv(output_file_path, index=False, encoding='utf-8-sig')
        print(f"변환 완료: {file} -> {output_file_name}")
    except Exception as e:
        print(f"파일 변환 중 오류 발생: {file} - {e}")

print("모든 파일 변환 작업 완료")
# Out:
# 변환 완료: 미숙아 연하 곤란_with_content.xlsx -> 미숙아 연하 곤란_with_content.csv
# 변환 완료: 미숙아 삼킴 문제_with_content.xlsx -> 미숙아 삼킴 문제_with_content.csv
# 변환 완료: 미숙아 모유수유 문제_with_content.xlsx -> 미숙아 모유수유 문제_with_content.csv
# 변환 완료: 미숙아 빨기 문제_with_content.xlsx -> 미숙아 빨기 문제_with_content.csv
# 변환 완료: 미숙아 수유 어려움_with_content.xlsx -> 미숙아 수유 어려움_with_content.csv
# 모든 파일 변환 작업 완료

# %% [markdown]
# # 전처리 진행

# %% [markdown]
# - 미숙아 연하 곤란

# %%
import pandas as pd
from bs4 import BeautifulSoup

# 파일 경로 설정
file_path = "/content/drive/MyDrive/tistoryblog/tistory_csv파일/미숙아 연하 곤란_with_content.csv"

# CSV 파일 불러오기
try:
    data = pd.read_csv(file_path, encoding='utf-8')
except UnicodeDecodeError:
    data = pd.read_csv(file_path, encoding='euc-kr')

# 데이터 확인
print("데이터 샘플:")
print(data.head())

# 불필요한 열 제거
data = data.drop(columns=['불필요한열'], errors='ignore')

# 결측치 처리
data = data.dropna()

# 날짜 변환
data['pubDate'] = pd.to_datetime(data['pubDate'])

# 중복 제거
data = data.drop_duplicates(subset=['title', 'link'])

# 텍스트 전처리 (HTML 태그 제거)
data['title'] = data['title'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())
data['content'] = data['content'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())

# 전처리 결과 확인
print("전처리 후 데이터 샘플:")
print(data.head())

# 결과 저장
data.to_csv('전처리된__tistory_미숙아 연하곤란.csv', index=False, encoding='utf-8-sig')
print("전처리 완료. 파일 저장됨.")
# Out:
# 데이터 샘플:
#                                     title  \
# 0                     소아 위 식도 역류 원인과 관리방법
# 1  흡인성 폐렴, 수인성 전염병(감염병) - 한자 인(끌 인, 인할 인)
# 2                흡인성 폐렴 원인, 일반 폐렴 차이, 치료법
# 3                    뇌성마비- CP/ 원인, 증상, 치료
# 4                  벨라콜린주 효과, 사용법, 부작용, 가격
#
#                                                 link     pubDate  \
# 0  https://momsso.com/entry/%EC%86%8C%EC%95%84-%E...  2024-12-27
# 1  https://streambook.tistory.com/entry/%ED%9D%A1...  2024-07-03
# 2  https://switzeattle.com/entry/%EB%B0%95%ED%95%...  2024-06-15
# 3  https://lovepodo.tistory.com/entry/%EB%87%8C%E...  2024-06-02
# 4  https://mangrove2023.tistory.com/282#google_vi...  2024-04-14
#
#                                              content
# 0  소아 위 식도 역류 원인과 관리방법\n본문 바로가기\n홈\n방명록\n메뉴\nHome...
# 1  흡인성 폐렴, 수인성 전염병(감염병) - 한자 인(끌 인, 인할 인)\n본문 바로가...
# 2  흡인성 폐렴 원인, 일반 폐렴 차이, 치료법\n본문 바로가기\n메뉴 바로가기\n티스...
# 3  뇌성마비- CP/ 원인, 증상, 치료\n리뷰하는 강아지\n홈\n브런치\netc\n뇌...
# ...

# %% [markdown]
# - 미숙아 삼킴 문제

# %%
import pandas as pd
from bs4 import BeautifulSoup

# 파일 경로 설정
file_path = "/content/drive/MyDrive/tistoryblog/tistory_csv파일/미숙아 삼킴 문제_with_content.csv"

# CSV 파일 불러오기
try:
    data = pd.read_csv(file_path, encoding='utf-8')
except UnicodeDecodeError:
    data = pd.read_csv(file_path, encoding='euc-kr')

# 데이터 확인
print("데이터 샘플:")
print(data.head())

# 불필요한 열 제거
data = data.drop(columns=['불필요한열'], errors='ignore')

# 결측치 처리
data = data.dropna()

# 날짜 변환
data['pubDate'] = pd.to_datetime(data['pubDate'])

# 중복 제거
data = data.drop_duplicates(subset=['title', 'link'])

# 텍스트 전처리 (HTML 태그 제거)
data['title'] = data['title'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())
data['content'] = data['content'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())

# 전처리 결과 확인
print("전처리 후 데이터 샘플:")
print(data.head())

# 결과 저장
data.to_csv('전처리된__tistory_미숙아 삼킴 문제.csv', index=False, encoding='utf-8-sig')
print("전처리 완료. 파일 저장됨.")
# Out:
# 데이터 샘플:
#                                               title  \
# 0             훼로바유서방정: 철 결핍성 빈혈 예방과 효과적인 사용법 완벽 가이드
# 1                         *독시마이신엔정 100mg*독시사이클린수화물*
# 2         소아 폐렴 원인, 진단, 증상, 통증, 치료, 병원, 명의, 합병증, 예후
# 3  신생아의 움직임과 반사(Rreflex) 정리 (aka. 소아치료 라면 알아야 할 반사)
# 4                   뇌성마비 초기 징후 파악하기 조기 진단을 위한 중요 정보
#
#                                                 link     pubDate  \
# 0  https://info.healingstoryit.kr/entry/%ED%9B%BC...  2024-12-13
# 1                https://okheesblog.tistory.com/3483  2024-11-11
# 2              https://feelyohanblog.tistory.com/281  2024-10-03
# 3                   https://pt27288.tistory.com/2117  2024-07-25
# 4  https://mindpoom.tistory.com/entry/%EB%87%8C%E...  2024-06-14
#
#                                              content
# 0  훼로바유서방정: 철 결핍성 빈혈 예방과 효과적인 사용법 완벽 가이드\n본문 바로가기...
# 1  *독시마이신엔정 100mg*독시사이클린수화물*\n옥히스블로그\n홈\n태그\n방명록\...
# 2  소아 폐렴 원인, 진단, 증상, 통증, 치료, 병원, 명의, 합병증, 예후\n본문 ...
# ...

# %% [markdown]
# - 미숙아 모유수유 문제

# %%
import pandas as pd
from bs4 import BeautifulSoup

# 파일 경로 설정
file_path = "/content/drive/MyDrive/tistoryblog/tistory_csv파일/미숙아 모유수유 문제_with_content.csv"

# CSV 파일 불러오기
try:
    data = pd.read_csv(file_path, encoding='utf-8')
except UnicodeDecodeError:
    data = pd.read_csv(file_path, encoding='euc-kr')

# 데이터 확인
print("데이터 샘플:")
print(data.head())

# 불필요한 열 제거
data = data.drop(columns=['불필요한열'], errors='ignore')

# 결측치 처리
data = data.dropna()

# 날짜 변환
data['pubDate'] = pd.to_datetime(data['pubDate'])

# 중복 제거
data = data.drop_duplicates(subset=['title', 'link'])

# 텍스트 전처리 (HTML 태그 제거)
data['title'] = data['title'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())
data['content'] = data['content'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())

# 전처리 결과 확인
print("전처리 후 데이터 샘플:")
print(data.head())

# 결과 저장
data.to_csv('전처리된__tistory_미숙아 모유수유 문제.csv', index=False, encoding='utf-8-sig')
print("전처리 완료. 파일 저장됨.")
# Out:
# 데이터 샘플:
#                                        title  \
# 0                        소아 위 식도 역류 원인과 관리방법
# 1               커피 속 카페인(caffeine), 독일까 약일까?
# 2              조산의 위험성과 예방법: 부모님이 꼭 알아야 할 정보
# 3  모든 엄마를 위한 선물! 산모/신생아 건강관리 지원 서비스, 지금 바로신청
# 4           신생아 황달 수치 원인 치료: 초보 부모를 위한 필수 정보
#
#                                                 link     pubDate  \
# 0  https://momsso.com/entry/%EC%86%8C%EC%95%84-%E...  2024-12-27
# 1  https://moneymonkey11.tistory.com/entry/%EC%BB...  2024-12-25
# 2  https://aamola.tistory.com/entry/%EC%A1%B0%EC%...  2024-12-24
# 3  https://body.k-xorud.com/entry/%EB%AA%A8%EB%93...  2024-12-23
# 4  https://tlsrlfn07.tistory.com/entry/%EC%8B%A0%...  2024-12-23
#
#                                              content
# 0  소아 위 식도 역류 원인과 관리방법\n본문 바로가기\n홈\n방명록\n메뉴\nHome...
# 1  커피 속 카페인(caffeine), 독일까 약일까?\n본문 바로가기\n커피 빈로그(...
# 2  조산의 위험성과 예방법: 부모님이 꼭 알아야 할 정보\n본문 바로가기\n모르겠는데\...
# 3  모든 엄마를 위한 선물! 산모/신생아 건강관리 지원 서비스, 지금 바로 신청!\n본...
# ...

# %% [markdown]
# - 미숙아 빨기 문제

# %%
import pandas as pd
from bs4 import BeautifulSoup

# 파일 경로 설정
file_path = "/content/drive/MyDrive/tistoryblog/tistory_csv파일/미숙아 빨기 문제_with_content.csv"

# CSV 파일 불러오기
try:
    data = pd.read_csv(file_path, encoding='utf-8')
except UnicodeDecodeError:
    data = pd.read_csv(file_path, encoding='euc-kr')

# 데이터 확인
print("데이터 샘플:")
print(data.head())

# 불필요한 열 제거
data = data.drop(columns=['불필요한열'], errors='ignore')

# 결측치 처리
data = data.dropna()

# 날짜 변환
data['pubDate'] = pd.to_datetime(data['pubDate'])

# 중복 제거
data = data.drop_duplicates(subset=['title', 'link'])

# 텍스트 전처리 (HTML 태그 제거)
data['title'] = data['title'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())
data['content'] = data['content'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())

# 전처리 결과 확인
print("전처리 후 데이터 샘플:")
print(data.head())

# 결과 저장
data.to_csv('전처리된__tistory_미숙아 빨기 문제.csv', index=False, encoding='utf-8-sig')
print("전처리 완료. 파일 저장됨.")
# Out:
# 데이터 샘플:
#                                        title  \
# 0                        소아 위 식도 역류 원인과 관리방법
# 1              미숙아 전용 제품 추천 (의류, 수유용품, 환경조성)
# 2                신생아 빨기반사: 성장과 모유수유의 중요한 시작점
# 3              신생아의 발달과정에서 반사 행동과 감각 및 학습 능력
# 4  신생아 반사의 종류: 모로 반사 바빈스키 반사외에 또 어떤 반사가 있을까?
#
#                                                 link     pubDate  \
# 0  https://momsso.com/entry/%EC%86%8C%EC%95%84-%E...  2024-12-27
# 1  https://melrang-coco.com/entry/%EB%AF%B8%EC%88...  2024-12-01
# 2  https://babystory24.tistory.com/entry/%EC%8B%A...  2024-11-23
# 3                      https://blog.lucky0530.com/42  2024-10-17
# 4                       https://2.chaechaerry.com/42  2024-08-29
#
#                                              content
# 0  소아 위 식도 역류 원인과 관리방법\n본문 바로가기\n홈\n방명록\n메뉴\nHome...
# 1  미숙아 전용 제품 추천 (의류, 수유용품, 환경조성)\n본문 바로가기\n햄토리맘의 ...
# 2  신생아 빨기반사: 성장과 모유수유의 중요한 시작점\n본문 바로가기\n초보아빠이야기\...
# 3  신생아의 발달과정에서 반사 행동과 감각 및 학습 능력\n본문 바로가기\n자유의여시\...
# ...

# %% [markdown]
# - 미숙아 수유 어려움

# %%
import pandas as pd
from bs4 import BeautifulSoup

# 파일 경로 설정
file_path = "/content/drive/MyDrive/tistoryblog/tistory_csv파일/미숙아 수유 어려움_with_content.csv"

# CSV 파일 불러오기
try:
    data = pd.read_csv(file_path, encoding='utf-8')
except UnicodeDecodeError:
    data = pd.read_csv(file_path, encoding='euc-kr')

# 데이터 확인
print("데이터 샘플:")
print(data.head())

# 불필요한 열 제거
data = data.drop(columns=['불필요한열'], errors='ignore')

# 결측치 처리
data = data.dropna()

# 날짜 변환
data['pubDate'] = pd.to_datetime(data['pubDate'])

# 중복 제거
data = data.drop_duplicates(subset=['title', 'link'])

# 텍스트 전처리 (HTML 태그 제거)
data['title'] = data['title'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())
data['content'] = data['content'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())

# 전처리 결과 확인
print("전처리 후 데이터 샘플:")
print(data.head())

# 결과 저장
data.to_csv('전처리된__tistory_미숙아 수유 어려움.csv', index=False, encoding='utf-8-sig')
print("전처리 완료. 파일 저장됨.")
# Out:
# 데이터 샘플:
#                                               title  \
# 0                        RSV 바이러스 증상 뜻 감염증 주의사항 총정리
# 1                     조산의 위험성과 예방법: 부모님이 꼭 알아야 할 정보
# 2                          이른둥이 생존율과 치료 방법: 희망의 발걸음
# 3  세기관지염(bronchiolitis) 원인, 증상, 검사와진단, 치료, 예방 및 합병증
# 4                                 신생아 황달 증상, 원인, 치료
#
#                                                 link     pubDate  \
# 0  https://money.ohohinfo.com/entry/RSV-%EB%B0%94...  2024-12-28
# 1  https://aamola.tistory.com/entry/%EC%A1%B0%EC%...  2024-12-24
# 2  https://top.kstory-1.com/entry/%EC%9D%B4%EB%A5...  2024-12-12
# 3                    https://soso0817.tistory.com/53  2024-12-10
# 4  https://alwaysthesun.tistory.com/entry/%EC%8B%...  2024-12-10
#
#                                              content
# 0  RSV 바이러스 증상 뜻 감염증 주의사항 총정리\n본문 바로가기\n메뉴 바로가기\n...
# 1  조산의 위험성과 예방법: 부모님이 꼭 알아야 할 정보\n본문 바로가기\n모르겠는데\...
# 2  …\n이른둥이 생존율과 치료 방법: 희망의 발걸음\n본문 바로가기\n건강 의학\n블...
# ...

# %% [markdown]
# # 시각화

# %%
# !apt-get update -qq
# !apt-get install -y fonts-nanum
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 56 not upgraded.

# %%
font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter
from konlpy.tag import Okt
import os

# 파일 경로 설정
folder_path = "/content/drive/MyDrive/tistoryblog/전처리_tistory"  # CSV 파일들이 저장된 폴더 경로
csv_files = [f for f in os.listdir(folder_path) if f.endswith('.csv')]

# 형태소 분석기 준비
okt = Okt()

# 키워드 저장용
all_keywords = []
trend_data = []

# 각 파일 처리
for file in csv_files:
    file_path = os.path.join(folder_path, file)
    print(f"Processing: {file}")

    # 파일 불러오기
    try:
        data = pd.read_csv(file_path, encoding='utf-8')
    except UnicodeDecodeError:
        data = pd.read_csv(file_path, encoding='euc-kr')

    # 날짜 변환
    data['pubDate'] = pd.to_datetime(data['pubDate'], errors='coerce')

    # 결측치 제거
    data = data.dropna(subset=['title', 'content', 'pubDate'])

    # HTML 태그 제거
    data['title'] = data['title'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())
    data['content'] = data['content'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())

    # 키워드 추출 및 저장
    for _, row in data.iterrows():
        tokens = okt.nouns(row['title']) + okt.nouns(row['content'])
        all_keywords.extend(tokens)

        # 연도별 키워드 추출
        trend_data.append({'year': row['pubDate'].year, 'keywords': tokens})

# 워드 클라우드 생성
print("Generating Word Cloud...")

# 폰트 경로 설정
font_path = "/usr/share/fonts/truetype/nanum/NanumGothic.ttf"  # 한글 폰트 파일 경로

word_counts = Counter(all_keywords)
wordcloud = WordCloud(font_path=font_path, background_color="white", width=800, height=400)
wordcloud.generate_from_frequencies(word_counts)

plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of All Keywords')
plt.show()

# 키워드 간 상관관계 분석 (빈도 기반)
print("Keyword Correlation Analysis...")
from itertools import combinations
from collections import defaultdict

# 키워드 상관관계 저장
correlation = defaultdict(Counter)

for item in trend_data:
    keywords = item['keywords']
    for pair in combinations(keywords, 2):
        correlation[pair[0]][pair[1]] += 1

# 상관관계 데이터프레임 생성
correlation_df = pd.DataFrame.from_dict(correlation, orient='index').fillna(0)

# 시기별 키워드 트렌드 분석
print("Keyword Trend Analysis...")
trend_df = pd.DataFrame(trend_data)
trend_df = trend_df.explode('keywords')
trend_trends = trend_df.groupby(['year', 'keywords']).size().reset_index(name='frequency')

# 시기별 키워드 변화 시각화
for keyword in word_counts.most_common(5):
    keyword_name = keyword[0]
    keyword_trend = trend_trends[trend_trends['keywords'] == keyword_name]

    plt.figure(figsize=(10, 5))
    plt.plot(keyword_trend['year'], keyword_trend['frequency'], marker='o')
    plt.title(f"Trend of '{keyword_name}' Over Time")
    plt.xlabel('Year')
    plt.ylabel('Frequency')
    plt.grid()
    plt.show()

print("Analysis Complete.")
# Out:
# Processing: 전처리된__tistory_미숙아 삼킴 문제.csv
# <ipython-input-45-b9ed8bd53f49>:37: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   data['title'] = data['title'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())
# Processing: 전처리된__tistory_미숙아 연하곤란.csv
# <ipython-input-45-b9ed8bd53f49>:37: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   data['title'] = data['title'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())
# Processing: 전처리된__tistory_미숙아 모유수유 문제.csv
# <ipython-input-45-b9ed8bd53f49>:37: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
# ...

# %% [markdown]
# - 불용어 처리 단계

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter
from konlpy.tag import Okt
import os
from bs4 import BeautifulSoup

# 키워드 리스트 정의
essential_keywords = ["모유수유","삼킴","연하 곤란","장애", "문제", "빨기", "수유", "구강","빠는 힘"]

stop_words = [
    '및','그','증','중','매우','또한','홈','약','더','등','때','첫','정도','수','것','경우','후''주','를''알','글','이내',
    '배','내','이','법','시','일','로','꼭','못','요','몸','전','은','말','유','정'',안','입','후','세','장','눈','과','거나',
    '주','의','데','알','를','생','란','양','병','점','균','속','해','안','간','목','뇌'
]

remove_words = [
    '본문','신생아','아기','미숙아','원인','아이','정도','때문','소아','임신','위해','능력','모든','기간','결핍','대부분',
    '태그','포함','조절','다른','일반','환경','기능','이유','효과','요인','치료','진단','확인','대사','제공','사항',
    '카테고리','조산','바로가기','방명록','검색','증상','출생','정보','로그인','사용','로그아웃','선택','운동','초기','간호',
    '블로그','음식','시작','글쓰기','메뉴','공급','가지','상황','통해','문제','엄마','둥이','효능','관련','산모','질병','감기',
    '우리','기준','갖아','머리','미만','어린이','부족','부분','육아','이해','제품','생리','산소','미숙','역할','진행','사이',
    '보기','로그인','방법','발생','관리','건강',' 질환','반응','감염','만삭','일','제대로','오늘','가장','자연','감소','피부',
    '의사','환자','성인','세포','가이드','상태','검사','영아','조기','생존','주의','지속','특징','생각','무엇','처음','물질',
    '의학','발견','보호','정상','이후','알속','생후','수치','자극','주로','대한','병원','하나','수도','분류','어려움','대해',
    '위험','저하','모두','유발','여러','가능성','이전','티스토리','약물','이상','장애','질환','바이러스','천문','시간','증가',
    '출산','유아','예방','시기','과정','신체','전체','도움','태아','종류','주요','동안','근육','다음','정의','단계','행동',
    '필수','의료','사람','성분','아동','체온','염증','유지','증후군','정리','세균','변화','부작용','연령','의미','생활','이야기',
    '분만','얼굴','형성','이유식','지식','보통','음식물','신경','출혈','따라서','준비','유아기','선천성','결과','자세',
    '융합','영향','섭취'
    ]

# 파일 경로 설정
folder_path = '/content/drive/MyDrive/tistoryblog/전처리_tistory'  # CSV 파일들이 저장된 폴더 경로
csv_files = [f for f in os.listdir(folder_path) if f.endswith('.csv')]

# 형태소 분석기 준비
okt = Okt()

# 키워드 저장용
all_keywords = []
trend_data = []

# 각 파일 처리
for file in csv_files:
    file_path = os.path.join(folder_path, file)
    print(f"Processing: {file}")

    # 파일 불러오기
    try:
        data = pd.read_csv(file_path, encoding='utf-8')
    except UnicodeDecodeError:
        data = pd.read_csv(file_path, encoding='euc-kr')

    # 날짜 변환
    data['pubDate'] = pd.to_datetime(data['pubDate'], errors='coerce')

    # 결측치 제거
    data = data.dropna(subset=['title', 'content', 'pubDate'])

    # HTML 태그 제거
    data['title'] = data['title'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())
    data['content'] = data['content'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())

    # 키워드 추출 및 저장
    for _, row in data.iterrows():
        tokens = okt.nouns(row['title']) + okt.nouns(row['content'])
        filtered_tokens = [word for word in tokens if word not in stop_words and word not in remove_words]
        all_keywords.extend(filtered_tokens)

        # 연도별 키워드 추출
        trend_data.append({'year': row['pubDate'].year, 'keywords': filtered_tokens})

# 워드 클라우드 생성
print("Generating Word Cloud...")

# 폰트 경로 설정
font_path = "/usr/share/fonts/truetype/nanum/NanumGothic.ttf"  # 한글 폰트 파일 경로

word_counts = Counter(all_keywords)
wordcloud = WordCloud(font_path=font_path, background_color="white", width=800, height=400)
wordcloud.generate_from_frequencies(word_counts)

plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of All Keywords')
plt.show()

# 키워드 간 상관관계 분석 (빈도 기반)
print("Keyword Correlation Analysis...")
from itertools import combinations
from collections import defaultdict

# 키워드 상관관계 저장
correlation = defaultdict(Counter)

for item in trend_data:
    keywords = item['keywords']
    for pair in combinations(keywords, 2):
        correlation[pair[0]][pair[1]] += 1

# 상관관계 데이터프레임 생성
correlation_df = pd.DataFrame.from_dict(correlation, orient='index').fillna(0)

print("Analysis Complete.")
# Out:
# Processing: 전처리된__tistory_미숙아 삼킴 문제.csv
# <ipython-input-75-a27d6f76feac>:63: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   data['title'] = data['title'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())
# Processing: 전처리된__tistory_미숙아 연하곤란.csv
# <ipython-input-75-a27d6f76feac>:63: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   data['title'] = data['title'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())
# Processing: 전처리된__tistory_미숙아 모유수유 문제.csv
# <ipython-input-75-a27d6f76feac>:63: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
# ...

# %% [markdown]
#  - 연도별 키워드 분석

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
from konlpy.tag import Okt
import os
from bs4 import BeautifulSoup

# 키워드 리스트 정의
essential_keywords = ["모유수유","삼킴","연하 곤란","장애", "문제", "빨기", "수유", "구강","빠는 힘"]

stop_words = [
    '및','그','증','중','매우','또한','홈','약','더','등','때','첫','정도','수','것','경우','후''주','를''알','글','이내',
    '배','내','이','법','시','일','로','꼭','못','요','몸','전','은','말','유','정'',안','입','후','세','장','눈','과','거나',
    '주','의','데','알','를','생','란','양','병','점','균','속','해','안','간','목','뇌'
]

remove_words = [
    '본문','신생아','아기','미숙아','원인','아이','정도','때문','소아','임신','위해','능력','모든','기간','결핍','대부분',
    '태그','포함','조절','다른','일반','환경','기능','이유','효과','요인','치료','진단','확인','대사','제공','사항',
    '카테고리','조산','바로가기','방명록','검색','증상','출생','정보','로그인','사용','로그아웃','선택','운동','초기','간호',
    '블로그','음식','시작','글쓰기','메뉴','공급','가지','상황','통해','문제','엄마','둥이','효능','관련','산모','질병','감기',
    '우리','기준','갖아','머리','미만','어린이','부족','부분','육아','이해','제품','생리','산소','미숙','역할','진행','사이',
    '보기','로그인','방법','발생','관리','건강',' 질환','반응','감염','만삭','일','제대로','오늘','가장','자연','감소','피부',
    '의사','환자','성인','세포','가이드','상태','검사','영아','조기','생존','주의','지속','특징','생각','무엇','처음','물질',
    '의학','발견','보호','정상','이후','알속','생후','수치','자극','주로','대한','병원','하나','수도','분류','어려움','대해',
    '위험','저하','모두','유발','여러','가능성','이전','티스토리','약물','이상','장애','질환','바이러스','천문','시간','증가',
    '출산','유아','예방','시기','과정','신체','전체','도움','태아','종류','주요','동안','근육','다음','정의','단계','행동',
    '필수','의료','사람','성분','아동','체온','염증','유지','증후군','정리','세균','변화','부작용','연령','의미','생활','이야기',
    '분만','얼굴','형성','이유식','지식','보통','음식물','신경','출혈','따라서','준비','유아기','선천성','결과','자세',
    '융합','영향','섭취'
    ]

# 파일 경로 설정
folder_path = "/content/drive/MyDrive/tistoryblog/전처리_tistory"  # CSV 파일들이 저장된 폴더 경로
csv_files = [f for f in os.listdir(folder_path) if f.endswith('.csv')]

# 형태소 분석기 준비
okt = Okt()

# 연도별 키워드 저장용
yearly_keywords = {}

# 각 파일 처리
for file in csv_files:
    file_path = os.path.join(folder_path, file)
    print(f"Processing: {file}")

    # 파일 불러오기
    try:
        data = pd.read_csv(file_path, encoding='utf-8')
    except UnicodeDecodeError:
        data = pd.read_csv(file_path, encoding='euc-kr')

    # 날짜 변환
    data['pubDate'] = pd.to_datetime(data['pubDate'], errors='coerce')

    # 결측치 제거
    data = data.dropna(subset=['title', 'content', 'pubDate'])

    # HTML 태그 제거
    data['title'] = data['title'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())
    data['content'] = data['content'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())

    # 연도별 키워드 추출 및 저장
    for _, row in data.iterrows():
        year = row['pubDate'].year
        tokens = okt.nouns(row['title']) + okt.nouns(row['content'])
        filtered_tokens = [word for word in tokens if word not in stop_words and word not in remove_words]

        if year not in yearly_keywords:
            yearly_keywords[year] = []
        yearly_keywords[year].extend(filtered_tokens)

# 연도별 키워드 빈도 분석
print("Analyzing yearly keyword trends...")
yearly_keyword_counts = {}

for year, keywords in yearly_keywords.items():
    yearly_keyword_counts[year] = Counter(keywords).most_common(10)  # 상위 10개 키워드

# 연도별 트렌드 시각화
for year, keyword_counts in sorted(yearly_keyword_counts.items()):
    keywords, counts = zip(*keyword_counts)

    plt.figure(figsize=(10, 5))
    plt.bar(keywords, counts)
    plt.title(f"Top Keywords in {year}")
    plt.xlabel("Keywords")
    plt.ylabel("Frequency")
    plt.xticks(rotation=45)
    plt.show()

print("Yearly trend analysis complete.")
# Out:
# Processing: 전처리된__tistory_미숙아 모유수유 문제.csv
# <ipython-input-9-047fd9cf9064>:61: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   data['title'] = data['title'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())
# Processing: 전처리된__tistory_미숙아 빨기 문제.csv
# <ipython-input-9-047fd9cf9064>:61: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   data['title'] = data['title'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())
# Processing: 전처리된__tistory_미숙아 삼킴 문제.csv
# <ipython-input-9-047fd9cf9064>:61: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
# ...

# %% [markdown]
# - Top rank 50 & word cloud

# %%
# 필요한 라이브러리 임포트
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
from wordcloud import WordCloud
from konlpy.tag import Okt
import os
from bs4 import BeautifulSoup

# 키워드 리스트 정의
essential_keywords = ["모유수유","삼킴","연하 곤란","장애", "문제", "빨기", "수유", "구강","빠는 힘"]

stop_words = [
    '및','그','증','중','매우','또한','홈','약','더','등','때','첫','정도','수','것','경우','후''주','를''알','글','이내',
    '배','내','이','법','시','일','로','꼭','못','요','몸','전','은','말','유','정'',안','입','후','세','장','눈','과','거나',
    '주','의','데','알','를','생','란','양','병','점','균','속','해','안','간','목','뇌'
]

remove_words = [
    '본문','신생아','아기','미숙아','원인','아이','정도','때문','소아','임신','위해','능력','모든','기간','결핍','대부분',
    '태그','포함','조절','다른','일반','환경','기능','이유','효과','요인','치료','진단','확인','대사','제공','사항',
    '카테고리','조산','바로가기','방명록','검색','증상','출생','정보','로그인','사용','로그아웃','선택','운동','초기','간호',
    '블로그','음식','시작','글쓰기','메뉴','공급','가지','상황','통해','문제','엄마','둥이','효능','관련','산모','질병','감기',
    '우리','기준','갖아','머리','미만','어린이','부족','부분','육아','이해','제품','생리','산소','미숙','역할','진행','사이',
    '보기','로그인','방법','발생','관리','건강',' 질환','반응','감염','만삭','일','제대로','오늘','가장','자연','감소','피부',
    '의사','환자','성인','세포','가이드','상태','검사','영아','조기','생존','주의','지속','특징','생각','무엇','처음','물질',
    '의학','발견','보호','정상','이후','알속','생후','수치','자극','주로','대한','병원','하나','수도','분류','어려움','대해',
    '위험','저하','모두','유발','여러','가능성','이전','티스토리','약물','이상','장애','질환','바이러스','천문','시간','증가',
    '출산','유아','예방','시기','과정','신체','전체','도움','태아','종류','주요','동안','근육','다음','정의','단계','행동',
    '필수','의료','사람','성분','아동','체온','염증','유지','증후군','정리','세균','변화','부작용','연령','의미','생활','이야기',
    '분만','얼굴','형성','이유식','지식','보통','음식물','신경','출혈','따라서','준비','유아기','선천성','결과','자세',
    '융합','영향','섭취'
    ]

# 폴더 경로 설정
folder_path = '/content/drive/MyDrive/tistoryblog/tistory_csv파일'  # 실제 경로에 맞게 수정

# 폴더 내 파일 목록 가져오기
csv_files = [f for f in os.listdir(folder_path) if f.endswith('.csv')]

# 형태소 분석기 준비
okt = Okt()

# 키워드 저장용
all_keywords = []

# 각 파일 처리
for file in csv_files:
    file_path = os.path.join(folder_path, file)
    print(f"Processing: {file}")

    # 파일 불러오기
    try:
        data = pd.read_csv(file_path, encoding='utf-8')
    except UnicodeDecodeError:
        data = pd.read_csv(file_path, encoding='euc-kr')

    # 결측치 제거
    data = data.dropna(subset=['title', 'content'])

    # HTML 태그 제거
    data['title'] = data['title'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())
    data['content'] = data['content'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())

    # 키워드 추출
    for _, row in data.iterrows():
        tokens = okt.nouns(row['title']) + okt.nouns(row['content'])
        filtered_tokens = [
            word for word in tokens
            if word not in stop_words and word not in remove_words and word not in essential_keywords
        ]
        all_keywords.extend(filtered_tokens)

# 상위 50개 키워드 추출
word_counts = Counter(all_keywords)
top_50_keywords = word_counts.most_common(200)

# 데이터프레임 생성
top_50_keywords_df = pd.DataFrame(top_50_keywords, columns=['Keyword', 'Frequency'])

# 워드 클라우드 생성
font_path = "/usr/share/fonts/truetype/nanum/NanumGothic.ttf"  # 한글 폰트 경로
wordcloud = WordCloud(font_path=font_path, background_color="white", width=800, height=400)
wordcloud.generate_from_frequencies(word_counts)

# 워드 클라우드 시각화
plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of All Keywords')
plt.show()

# 상위 50개 키워드 출력
print(top_50_keywords_df)

# CSV 파일로 저장
top_50_keywords_df.to_csv("top_50_keywords(daumtistory).csv", index=False, encoding='utf-8-sig')
print("상위 50개 키워드 데이터가 'top_50_keywords.csv(daumtistory)'로 저장되었습니다.")
# Out:
# Processing: 미숙아 연하 곤란_with_content.csv
# <ipython-input-9-c18493fd70d1>:62: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   data['title'] = data['title'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())
# Processing: 미숙아 삼킴 문제_with_content.csv
# <ipython-input-9-c18493fd70d1>:62: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   data['title'] = data['title'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())
# Processing: 미숙아 모유수유 문제_with_content.csv
# <ipython-input-9-c18493fd70d1>:62: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
# ...
