# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
from bs4 import BeautifulSoup

# %%
# !pip install pandas openpyxl beautifulsoup4 requests

# %%
import sys

# Google Colab 환경에서 실행 중인지 확인
if 'google.colab' in sys.modules:
    # debconf를 Noninteractive 모드로 설정
    # !echo 'debconf debconf/frontend select Noninteractive' | debconf-set-selections

    # fonts-nanum 패키지를 설치
    # !sudo apt-get -qq -y install fonts-nanum

    # Matplotlib의 폰트 매니저 가져오기
    import matplotlib.font_manager as fm

    # 나눔 폰트의 시스템 경로 찾기
    font_files = fm.findSystemFonts(fontpaths=['/usr/share/fonts/truetype/nanum'])

    # 찾은 각 나눔 폰트를 Matplotlib 폰트 매니저에 추가
    for fpath in font_files:
        fm.fontManager.addfont(fpath)
# Out:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 124565 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...

# %%
# !pip install requests beautifulsoup4 pandas matplotlib konlpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 42.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.9/493.9 kB 18.4 MB/s eta 0:00:00
# ...

# %%
# Import matplotlib and matplotlib.pyplot
import matplotlib
import matplotlib.pyplot as plt

# Configure the font family to 'NanumGothic' and then to 'NanumBarunGothic'
plt.rcParams['font.family'] = 'NanumGothic'    #사용 방법1
plt.rc('font', family='NanumBarunGothic', size=11) #사용 방법2
print(plt.rcParams['font.family'], plt.rcParams['font.size'])   # 폰트확인
# Out:
# ['NanumBarunGothic'] 11.0

# %% [markdown]
# # 각 검색어 마다 content 끓어오기

# %% [markdown]
# - 미숙아 모유수유 문제

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# Load the data from the Excel file
file_path = '/content/drive/MyDrive/daum_news/미숙아 모유수유 문제.xlsx'
data = pd.read_excel(file_path)

# Function to scrape article content from a given link
def scrape_article_content(link):
    try:
        response = requests.get(link, timeout=10)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')

        # Example: Extracting the main content (you may need to adjust the selector based on the website's structure)
        article_content = soup.find('div', class_='article_view')
        if article_content:
            return article_content.get_text(strip=True)
        else:
            return "Content not found"
    except Exception as e:
        return f"Error: {e}"

# Prepare a list to store the scraped data
scraped_data = []

# Loop through each row in the DataFrame to scrape content
for index, row in data.iterrows():
    title = row['title']
    link = row['link']
    pub_date = row['pubDate']

    # Scrape the article content
    content = scrape_article_content(link)

    # Append the result to the list
    scraped_data.append({
        'title': title,
        'link': link,
        'pubDate': pub_date,
        'content': content
    })

    # To avoid being blocked, wait a bit between requests
    time.sleep(1)

# Convert the scraped data into a DataFrame
scraped_df = pd.DataFrame(scraped_data)

# Save the DataFrame to a CSV file
output_file = '/content/drive/MyDrive/daum_news/daum_미숙아 모유수유 문제.csv'
scraped_df.to_csv(output_file, index=False, encoding='utf-8-sig')

print(f"Scraping complete. Data saved to {output_file}")
# Out:
# Scraping complete. Data saved to /content/drive/MyDrive/daum_news/daum_미숙아 모유수유 문제.csv

# %% [markdown]
# - 미숙아 연하 곤란

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# Load the data from the Excel file
file_path = '/content/drive/MyDrive/daum_news/미숙아 연하 곤란.xlsx'
data = pd.read_excel(file_path)

# Function to scrape article content from a given link
def scrape_article_content(link):
    try:
        response = requests.get(link, timeout=10)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')

        # Example: Extracting the main content (you may need to adjust the selector based on the website's structure)
        article_content = soup.find('div', class_='article_view')
        if article_content:
            return article_content.get_text(strip=True)
        else:
            return "Content not found"
    except Exception as e:
        return f"Error: {e}"

# Prepare a list to store the scraped data
scraped_data = []

# Loop through each row in the DataFrame to scrape content
for index, row in data.iterrows():
    title = row['title']
    link = row['link']
    pub_date = row['pubDate']

    # Scrape the article content
    content = scrape_article_content(link)

    # Append the result to the list
    scraped_data.append({
        'title': title,
        'link': link,
        'pubDate': pub_date,
        'content': content
    })

    # To avoid being blocked, wait a bit between requests
    time.sleep(1)

# Convert the scraped data into a DataFrame
scraped_df = pd.DataFrame(scraped_data)

# Save the DataFrame to a CSV file
output_file = '/content/drive/MyDrive/daum_news/daum_미숙아 연하 곤란.csv'
scraped_df.to_csv(output_file, index=False, encoding='utf-8-sig')

print(f"Scraping complete. Data saved to {output_file}")
# Out:
# Scraping complete. Data saved to /content/drive/MyDrive/daum_news/daum_미숙아 연하 곤란.csv

# %% [markdown]
# - 미숙아 수유 어려움

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# Load the data from the Excel file
file_path = '/content/drive/MyDrive/daum_news/미숙아 수유 어려움.xlsx'
data = pd.read_excel(file_path)

# Function to scrape article content from a given link
def scrape_article_content(link):
    try:
        response = requests.get(link, timeout=10)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')

        # Example: Extracting the main content (you may need to adjust the selector based on the website's structure)
        article_content = soup.find('div', class_='article_view')
        if article_content:
            return article_content.get_text(strip=True)
        else:
            return "Content not found"
    except Exception as e:
        return f"Error: {e}"

# Prepare a list to store the scraped data
scraped_data = []

# Loop through each row in the DataFrame to scrape content
for index, row in data.iterrows():
    title = row['title']
    link = row['link']
    pub_date = row['pubDate']

    # Scrape the article content
    content = scrape_article_content(link)

    # Append the result to the list
    scraped_data.append({
        'title': title,
        'link': link,
        'pubDate': pub_date,
        'content': content
    })

    # To avoid being blocked, wait a bit between requests
    time.sleep(1)

# Convert the scraped data into a DataFrame
scraped_df = pd.DataFrame(scraped_data)

# Save the DataFrame to a CSV file
output_file = '/content/drive/MyDrive/daum_news/daum_미숙아 수유 어려움.csv'
scraped_df.to_csv(output_file, index=False, encoding='utf-8-sig')

print(f"Scraping complete. Data saved to {output_file}")
# Out:
# Scraping complete. Data saved to /content/drive/MyDrive/daum_news/daum_미숙아 수유 어려움.csv

# %% [markdown]
# - 미숙아 삼킴 문제

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# Load the data from the Excel file
file_path = '/content/drive/MyDrive/daum_news/미숙아 삼킴 문제.xlsx'
data = pd.read_excel(file_path)

# Function to scrape article content from a given link
def scrape_article_content(link):
    try:
        response = requests.get(link, timeout=10)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')

        # Example: Extracting the main content (you may need to adjust the selector based on the website's structure)
        article_content = soup.find('div', class_='article_view')
        if article_content:
            return article_content.get_text(strip=True)
        else:
            return "Content not found"
    except Exception as e:
        return f"Error: {e}"

# Prepare a list to store the scraped data
scraped_data = []

# Loop through each row in the DataFrame to scrape content
for index, row in data.iterrows():
    title = row['title']
    link = row['link']
    pub_date = row['pubDate']

    # Scrape the article content
    content = scrape_article_content(link)

    # Append the result to the list
    scraped_data.append({
        'title': title,
        'link': link,
        'pubDate': pub_date,
        'content': content
    })

    # To avoid being blocked, wait a bit between requests
    time.sleep(1)

# Convert the scraped data into a DataFrame
scraped_df = pd.DataFrame(scraped_data)

# Save the DataFrame to a CSV file
output_file = '/content/drive/MyDrive/daum_news/daum_미숙아 삼킴 문제.csv'
scraped_df.to_csv(output_file, index=False, encoding='utf-8-sig')

print(f"Scraping complete. Data saved to {output_file}")
# Out:
# Scraping complete. Data saved to /content/drive/MyDrive/daum_news/daum_미숙아 삼킴 문제.csv

# %% [markdown]
# - 미숙아 빨기 문제

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# Load the data from the Excel file
file_path = '/content/drive/MyDrive/daum_news/미숙아 빨기 문제.xlsx'
data = pd.read_excel(file_path)

# Function to scrape article content from a given link
def scrape_article_content(link):
    try:
        response = requests.get(link, timeout=10)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')

        # Example: Extracting the main content (you may need to adjust the selector based on the website's structure)
        article_content = soup.find('div', class_='article_view')
        if article_content:
            return article_content.get_text(strip=True)
        else:
            return "Content not found"
    except Exception as e:
        return f"Error: {e}"

# Prepare a list to store the scraped data
scraped_data = []

# Loop through each row in the DataFrame to scrape content
for index, row in data.iterrows():
    title = row['title']
    link = row['link']
    pub_date = row['pubDate']

    # Scrape the article content
    content = scrape_article_content(link)

    # Append the result to the list
    scraped_data.append({
        'title': title,
        'link': link,
        'pubDate': pub_date,
        'content': content
    })

    # To avoid being blocked, wait a bit between requests
    time.sleep(1)

# Convert the scraped data into a DataFrame
scraped_df = pd.DataFrame(scraped_data)

# Save the DataFrame to a CSV file
output_file = '/content/drive/MyDrive/daum_news/daum_미숙아 빨기 문제.csv'
scraped_df.to_csv(output_file, index=False, encoding='utf-8-sig')

print(f"Scraping complete. Data saved to {output_file}")
# Out:
# Scraping complete. Data saved to /content/drive/MyDrive/daum_news/daum_미숙아 빨기 문제.csv

# %% [markdown]
# # 전처리 진행

# %% [markdown]
# - 미숙아 연하 곤란

# %%
import pandas as pd
from bs4 import BeautifulSoup

# 파일 경로 설정
file_path = "/content/drive/MyDrive/daum_news/com_daum/daum_미숙아 연하 곤란.csv"

# CSV 파일 불러오기
try:
    data = pd.read_csv(file_path, encoding='utf-8')
except UnicodeDecodeError:
    data = pd.read_csv(file_path, encoding='euc-kr')

# 데이터 확인
print("데이터 샘플:")
print(data.head())

# 불필요한 열 제거
data = data.drop(columns=['불필요한열'], errors='ignore')

# 결측치 처리
data = data.dropna()

# 날짜 변환
data['pubDate'] = pd.to_datetime(data['pubDate'])

# 중복 제거
data = data.drop_duplicates(subset=['title', 'link'])

# 텍스트 전처리 (HTML 태그 제거)
data['title'] = data['title'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())
data['content'] = data['content'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())

# 전처리 결과 확인
print("전처리 후 데이터 샘플:")
print(data.head())

# 결과 저장
data.to_csv('전처리된__daumnews_미숙아 연하곤란.csv', index=False, encoding='utf-8-sig')
print("전처리 완료. 파일 저장됨.")
# Out:
# 데이터 샘플:
#                                       title  \
# 0  [건강한 가족] 호흡·소화기 복합 증상 환아, 의료진 팀워크로 맞춤 치료
# 1              발달 느린 아이…혹시 '뇌성마비'일까? [건강톡톡]
#
#                                      link     pubDate  \
# 0  https://v.daum.net/v/20210517000607446  2021-05-17
# 1  https://v.daum.net/v/20230330193115923  2023-03-30
#
#                                              content
# 0  ━[병원 탐방] 세브란스 어린이병원김하연(17·가명)양은 진행성 신경 질환인 리 증...
# 1  뇌성마비는 출생 전 뇌가 형성되는 과정에서 생기는 뇌 기형이나, 출생 중 혹은 출생...
# 전처리 후 데이터 샘플:
#                                       title  \
# 0  [건강한 가족] 호흡·소화기 복합 증상 환아, 의료진 팀워크로 맞춤 치료
# 1              발달 느린 아이…혹시 '뇌성마비'일까? [건강톡톡]
#
#                                      link    pubDate  \
# 0  https://v.daum.net/v/20210517000607446 2021-05-17
# 1  https://v.daum.net/v/20230330193115923 2023-03-30
#
#                                              content
# 0  ━[병원 탐방] 세브란스 어린이병원김하연(17·가명)양은 진행성 신경 질환인 리 증...
# 1  뇌성마비는 출생 전 뇌가 형성되는 과정에서 생기는 뇌 기형이나, 출생 중 혹은 출생...
# ...

# %% [markdown]
# - 미숙아 수유 어려움

# %%
import pandas as pd
from bs4 import BeautifulSoup

# 파일 경로 설정
file_path = "/content/drive/MyDrive/daum_news/com_daum/daum_미숙아 수유 어려움.csv"

# CSV 파일 불러오기
try:
    data = pd.read_csv(file_path, encoding='utf-8')
except UnicodeDecodeError:
    data = pd.read_csv(file_path, encoding='euc-kr')

# 데이터 확인
print("데이터 샘플:")
print(data.head())

# 불필요한 열 제거
data = data.drop(columns=['불필요한열'], errors='ignore')

# 결측치 처리
data = data.dropna()

# 날짜 변환
data['pubDate'] = pd.to_datetime(data['pubDate'])

# 중복 제거
data = data.drop_duplicates(subset=['title', 'link'])

# 텍스트 전처리 (HTML 태그 제거)
data['title'] = data['title'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())
data['content'] = data['content'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())

# 전처리 결과 확인
print("전처리 후 데이터 샘플:")
print(data.head())

# 결과 저장
data.to_csv('전처리된__daumnews_미숙아 수유 어려움.csv', index=False, encoding='utf-8-sig')
print("전처리 완료. 파일 저장됨.")
# Out:
# 데이터 샘플:
#                                               title  \
# 0                    "이대엄마아기병원, 저출산 시대 희망의 병원으로 도약"
# 1                      이대엄마아기병원, 저출산 시대 희망의 병원으로 도약
# 2       “태어나줘서 고마워” 260g ‘예랑이’ 숱한 고비 넘기고 3.19㎏으로 퇴원
# 3       512g ‘초극소미숙아’, 3.68kg로 퇴원하기까지… 5개월의 ‘성장 사진’
# 4  [꼬꼬무 찐리뷰] 3살도 안 된 세 자매의 연이은 사망…보험금 노린 악인은 '엄마'였다
#
#                                      link     pubDate  \
# 0  https://v.daum.net/v/20241120160718697  2024-11-20
# 1  https://v.daum.net/v/20241120144755036  2024-11-20
# 2  https://v.daum.net/v/20241113094649388  2024-11-13
# 3  https://v.daum.net/v/20241030153948879  2024-10-30
# 4  https://v.daum.net/v/20240719112713790  2024-07-19
#
#                                              content
# 0  이대엄마아기병원은 지난 13일 지하2층 대강당에서 분만 4000건 달성 기념식을 개...
# 1  [이데일리 안치영 기자] 이대엄마아기병원이 개원 이후 고위험 산모와 신생아를 안전하...
# 2  지난 4월 22일 국내에서 가장 적은 몸무게인 260g으로 태어난 아기 예랑이 모습...
# 3  512g의 초극소미숙아가 약 5개월의 병원 생활을 마치고 3.68kg의 몸무게로 건...
# ...

# %% [markdown]
# - 미숙아 삼킴 문제

# %%
import pandas as pd
from bs4 import BeautifulSoup

# 파일 경로 설정
file_path = "/content/drive/MyDrive/daum_news/com_daum/daum_미숙아 삼킴 문제.csv"

# CSV 파일 불러오기
try:
    data = pd.read_csv(file_path, encoding='utf-8')
except UnicodeDecodeError:
    data = pd.read_csv(file_path, encoding='euc-kr')

# 데이터 확인
print("데이터 샘플:")
print(data.head())

# 불필요한 열 제거
data = data.drop(columns=['불필요한열'], errors='ignore')

# 결측치 처리
data = data.dropna()

# 날짜 변환
data['pubDate'] = pd.to_datetime(data['pubDate'])

# 중복 제거
data = data.drop_duplicates(subset=['title', 'link'])

# 텍스트 전처리 (HTML 태그 제거)
data['title'] = data['title'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())
data['content'] = data['content'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())

# 전처리 결과 확인
print("전처리 후 데이터 샘플:")
print(data.head())

# 결과 저장
data.to_csv('전처리된__daumnews_미숙아 삼킴 문제.csv', index=False, encoding='utf-8-sig')
print("전처리 완료. 파일 저장됨.")
# Out:
# 데이터 샘플:
#                                                title  \
# 0           [건강한 가족] 호흡·소화기 복합 증상 환아, 의료진 팀워크로 맞춤 치료
# 1                  클림트의 '키스'..의학의 관점에서 해부하다 外 [병원소식]
# 2  우유로 연명하는 4세 아들 “배 속에서도 못 먹어, 40주 넘기고도 미숙아”(금쪽)...
#
#                                      link     pubDate  \
# 0  https://v.daum.net/v/20210517000607446  2021-05-17
# 1  https://v.daum.net/v/20211222101702360  2021-12-22
# 2  https://v.daum.net/v/20240224085457011  2024-02-24
#
#                                              content
# 0  ━[병원 탐방] 세브란스 어린이병원김하연(17·가명)양은 진행성 신경 질환인 리 증...
# 1  클림트의 ‘키스’…의학의 관점에서 해부하다= 20세기 최고 걸작 중 하나로 꼽히며 ...
# 2  채널A ‘요즘 육아-금쪽같은 내 새끼’채널A ‘요즘 육아-금쪽같은 내 새끼’[뉴스엔...
# 전처리 후 데이터 샘플:
#                                                title  \
# 0           [건강한 가족] 호흡·소화기 복합 증상 환아, 의료진 팀워크로 맞춤 치료
# 1                  클림트의 '키스'..의학의 관점에서 해부하다 外 [병원소식]
# 2  우유로 연명하는 4세 아들 “배 속에서도 못 먹어, 40주 넘기고도 미숙아”(금쪽)...
#
#                                      link    pubDate  \
# ...

# %% [markdown]
# - 미숙아 빨기 문제

# %%
import pandas as pd
from bs4 import BeautifulSoup

# 파일 경로 설정
file_path = "/content/drive/MyDrive/daum_news/com_daum/daum_미숙아 빨기 문제.csv"

# CSV 파일 불러오기
try:
    data = pd.read_csv(file_path, encoding='utf-8')
except UnicodeDecodeError:
    data = pd.read_csv(file_path, encoding='euc-kr')

# 데이터 확인
print("데이터 샘플:")
print(data.head())

# 불필요한 열 제거
data = data.drop(columns=['불필요한열'], errors='ignore')

# 결측치 처리
data = data.dropna()

# 날짜 변환
data['pubDate'] = pd.to_datetime(data['pubDate'])

# 중복 제거
data = data.drop_duplicates(subset=['title', 'link'])

# 텍스트 전처리 (HTML 태그 제거)
data['title'] = data['title'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())
data['content'] = data['content'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())

# 전처리 결과 확인
print("전처리 후 데이터 샘플:")
print(data.head())

# 결과 저장
data.to_csv('전처리된__daumnews_미숙아 빨기 문제.csv', index=False, encoding='utf-8-sig')
print("전처리 완료. 파일 저장됨.")
# Out:
# 데이터 샘플:
#                                    title  \
# 0             [해외입양과 돈]② 입양인들이 갈망하는 '진실'
# 1  "모유수유 좋은데 넌 왜 안 했어? 비난 말고 모자동실부터 늘려야"
#
#                                      link     pubDate  \
# 0  https://v.daum.net/v/20231102200502645  2023-11-02
# 1  https://v.daum.net/v/20210811155905219  2021-08-11
#
#                                              content
# 0  한국은 자국 아이를 해외로 가장 오래, 가장 많이 입양 보낸 국가다. 70년간 20...
# 1  【베이비뉴스 권현경 기자】세계보건기구(WHO)에서는 출산 후 1시간 이내 엄마 젖을...
# 전처리 후 데이터 샘플:
#                                    title  \
# 0             [해외입양과 돈]② 입양인들이 갈망하는 '진실'
# 1  "모유수유 좋은데 넌 왜 안 했어? 비난 말고 모자동실부터 늘려야"
#
#                                      link    pubDate  \
# 0  https://v.daum.net/v/20231102200502645 2023-11-02
# 1  https://v.daum.net/v/20210811155905219 2021-08-11
#
#                                              content
# 0  한국은 자국 아이를 해외로 가장 오래, 가장 많이 입양 보낸 국가다. 70년간 20...
# 1  【베이비뉴스 권현경 기자】세계보건기구(WHO)에서는 출산 후 1시간 이내 엄마 젖을...
# 전처리 완료. 파일 저장됨.

# %% [markdown]
# - 미숙아 모유수유 문제

# %%
import pandas as pd
from bs4 import BeautifulSoup

# 파일 경로 설정
file_path = "/content/drive/MyDrive/daum_news/com_daum/daum_미숙아 모유수유 문제.csv"

# CSV 파일 불러오기
try:
    data = pd.read_csv(file_path, encoding='utf-8')
except UnicodeDecodeError:
    data = pd.read_csv(file_path, encoding='euc-kr')

# 데이터 확인
print("데이터 샘플:")
print(data.head())

# 불필요한 열 제거
data = data.drop(columns=['불필요한열'], errors='ignore')

# 결측치 처리
data = data.dropna()

# 날짜 변환
data['pubDate'] = pd.to_datetime(data['pubDate'])

# 중복 제거
data = data.drop_duplicates(subset=['title', 'link'])

# 텍스트 전처리 (HTML 태그 제거)
data['title'] = data['title'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())
data['content'] = data['content'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())

# 전처리 결과 확인
print("전처리 후 데이터 샘플:")
print(data.head())

# 결과 저장
data.to_csv('전처리된__daumnews_미숙아 모유수유 문제.csv', index=False, encoding='utf-8-sig')
print("전처리 완료. 파일 저장됨.")
# Out:
# 데이터 샘플:
#                                               title  \
# 0           기침 100일 가는 '백일해'.. "임신부, 백신 접종해야" [닥터M]
# 1  [꼬꼬무 찐리뷰] 3살도 안 된 세 자매의 연이은 사망…보험금 노린 악인은 '엄마'였다
# 2                      "출산의 문 밀양시가 열어드려요"…모자보건사업 확대
# 3               국내 미숙아 생존율 89.9%로 높아져...생존율 높인 요인은?
# 4                420g에서 3.5㎏으로…초미숙아 175일 만에 건강하게 퇴원
#
#                                      link     pubDate  \
# 0  https://v.daum.net/v/20241221070202545  2024-12-21
# 1  https://v.daum.net/v/20241221070202545  2024-12-21
# 2  https://v.daum.net/v/20240128064145381  2024-01-28
# 3  https://v.daum.net/v/20231120150115232  2023-11-20
# 4  https://v.daum.net/v/20231004091636193  2023-10-04
#
#                                              content
# 0  ■ 진행 : 이충훈 아나운서■ 출연 : 김진규 교수[이충훈 아나운서]안녕하세요. 반...
# 1  ■ 진행 : 이충훈 아나운서■ 출연 : 김진규 교수[이충훈 아나운서]안녕하세요. 반...
# 2  [밀양=뉴시스] 밀양시가 배우자와 함께하는 임산부 건강교실을 운영하고 있다. (사진...
# 3  최근 결혼 연령이 늦어지면서 자연스레 고령 출산 비율이 증가했다. 이러한 임산부 고...
# ...

# %% [markdown]
# # 시각화

# %%
# !apt-get update -qq
# !apt-get install -y fonts-nanum
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 56 not upgraded.

# %%
font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter
from konlpy.tag import Okt
import os

# 파일 경로 설정
folder_path = "/content/drive/MyDrive/daum_news/pre_daum_news"  # CSV 파일들이 저장된 폴더 경로
csv_files = [f for f in os.listdir(folder_path) if f.endswith('.csv')]

# 형태소 분석기 준비
okt = Okt()

# 키워드 저장용
all_keywords = []
trend_data = []

# 각 파일 처리
for file in csv_files:
    file_path = os.path.join(folder_path, file)
    print(f"Processing: {file}")

    # 파일 불러오기
    try:
        data = pd.read_csv(file_path, encoding='utf-8')
    except UnicodeDecodeError:
        data = pd.read_csv(file_path, encoding='euc-kr')

    # 날짜 변환
    data['pubDate'] = pd.to_datetime(data['pubDate'], errors='coerce')

    # 결측치 제거
    data = data.dropna(subset=['title', 'content', 'pubDate'])

    # HTML 태그 제거
    data['title'] = data['title'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())
    data['content'] = data['content'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())

    # 키워드 추출 및 저장
    for _, row in data.iterrows():
        tokens = okt.nouns(row['title']) + okt.nouns(row['content'])
        all_keywords.extend(tokens)

        # 연도별 키워드 추출
        trend_data.append({'year': row['pubDate'].year, 'keywords': tokens})

# 워드 클라우드 생성
print("Generating Word Cloud...")

# 폰트 경로 설정
font_path = "/usr/share/fonts/truetype/nanum/NanumGothic.ttf"  # 한글 폰트 파일 경로

word_counts = Counter(all_keywords)
wordcloud = WordCloud(font_path=font_path, background_color="white", width=800, height=400)
wordcloud.generate_from_frequencies(word_counts)

plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of All Keywords')
plt.show()

# 키워드 간 상관관계 분석 (빈도 기반)
print("Keyword Correlation Analysis...")
from itertools import combinations
from collections import defaultdict

# 키워드 상관관계 저장
correlation = defaultdict(Counter)

for item in trend_data:
    keywords = item['keywords']
    for pair in combinations(keywords, 2):
        correlation[pair[0]][pair[1]] += 1

# 상관관계 데이터프레임 생성
correlation_df = pd.DataFrame.from_dict(correlation, orient='index').fillna(0)

# 시기별 키워드 트렌드 분석
print("Keyword Trend Analysis...")
trend_df = pd.DataFrame(trend_data)
trend_df = trend_df.explode('keywords')
trend_trends = trend_df.groupby(['year', 'keywords']).size().reset_index(name='frequency')

# 시기별 키워드 변화 시각화
for keyword in word_counts.most_common(5):
    keyword_name = keyword[0]
    keyword_trend = trend_trends[trend_trends['keywords'] == keyword_name]

    plt.figure(figsize=(10, 5))
    plt.plot(keyword_trend['year'], keyword_trend['frequency'], marker='o')
    plt.title(f"Trend of '{keyword_name}' Over Time")
    plt.xlabel('Year')
    plt.ylabel('Frequency')
    plt.grid()
    plt.show()

print("Analysis Complete.")
# Out:
# Processing: 전처리된__daumnews_미숙아 삼킴 문제.csv
# Processing: 전처리된__daumnews_미숙아 빨기 문제.csv
# Processing: 전처리된__daumnews_미숙아 연하곤란.csv
# Processing: 전처리된__daumnews_미숙아 모유수유 문제.csv
# Processing: 전처리된__daumnews_미숙아 수유 어려움.csv
# Generating Word Cloud...
# Keyword Correlation Analysis...
# Keyword Trend Analysis...
# Analysis Complete.

# %% [markdown]
# # 불용어 처리 단계

# %% [markdown]
# - 워드 클라우드

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter
from konlpy.tag import Okt
import os
from bs4 import BeautifulSoup

# 키워드 리스트 정의
essential_keywords = ["모유수유","삼킴","연하 곤란","장애", "문제", "빨기", "수유", "구강","빠는 힘"]

stop_words = [
    '가', '과', '지', '합니다', '이다', '하는', '하는것', '한', '그', '이', '를', '에', '에서', '와',
    '의', '는', '들', '도', '으로', '것', '수', '있다', '되다', '들', '및', '가', '고', '적', '더', '잘','기','달',
    '게', '등을', '라는', '하다가', '하면','내','이충','명','거','진','수가','계','또','재','안','번','세','일','며',
    '건','전','철','팀','때','말','최','딸','초','날','비','시','주','로','정','등','곳','뒤','후','제','김','원','정',
    '두','해','거의','양','개','차','증','걸','앞','세'',중','생','라며','나','점','알','훈','무','왜','저','실','줄',
    '남','병','율','살','속','애','첫','중','씨','면서','데','몇'
]

remove_words = [
    '접종','교수','통해','이후','임산부','진료','이상','약','모두','입원','지난','보고','청소년','때문','어려움','산모',
    '사진','진단','여러','문제','의사','간호사','사회','모든','은행','관리','가지','보험','당시','발생','설명','국내','미국',
    '건강','상황','입양','증가','음식','사랑','세계','시작','미숙아','아이','아기','위해','서비스','산부인과','조산','다른','처음',
    '아산병원','건우','가치','한국','정부','대해','상태','운영','위험','형사','미만','영향','원인','감소','기자','얘기','출생','태아',
    '학회','제공','교육','집중','권장','직후','둥이','출산''분만','일반','최선','사망','거의','기간','부부','효과','동안','미국','포함',
    '사람','서울','관련','예방','모습','기적','현재','경희대','뉴스','방문','사용','최근','먹이','이야기','계속','신생아','의료','병원',
    '치료','소아','출산','엄마','퇴원','경우','가장','생각','키스','시기','예방접종','중앙대','지름','정도','매일','확인','진행','중환자실',
    '퇴원','대한','생명','민서','미군','기준','쌍둥이','제대로','시술','수도','보호자','금지','하나','초기','관찰','아빠','이제','세상','시행',
    '백신','선생님','정상','자궁','전달','김진규','응급','여성','자세','하루','정보','신후','임신','환자','또한','분만','우리','몸','지금',
    '약물','볼','기도','시스템','가슴','결핍','김애란','사업','마음','인간','유아','베이비','강동','콜','의정부','지역','증상','임신부','질환',
    '설립','생후','수술','수빈','면역','확진','약시','기증','감염','보험금','기병','코로나','열','수사','그때','예찬','감기','조사원','못','백일해',
    '사건','둘째'
    ]

# 파일 경로 설정
folder_path = '/content/drive/MyDrive/daum_news/pre_daum_news'  # CSV 파일들이 저장된 폴더 경로
csv_files = [f for f in os.listdir(folder_path) if f.endswith('.csv')]

# 형태소 분석기 준비
okt = Okt()

# 키워드 저장용
all_keywords = []
trend_data = []

# 각 파일 처리
for file in csv_files:
    file_path = os.path.join(folder_path, file)
    print(f"Processing: {file}")

    # 파일 불러오기
    try:
        data = pd.read_csv(file_path, encoding='utf-8')
    except UnicodeDecodeError:
        data = pd.read_csv(file_path, encoding='euc-kr')

    # 날짜 변환
    data['pubDate'] = pd.to_datetime(data['pubDate'], errors='coerce')

    # 결측치 제거
    data = data.dropna(subset=['title', 'content', 'pubDate'])

    # HTML 태그 제거
    data['title'] = data['title'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())
    data['content'] = data['content'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())

    # 키워드 추출 및 저장
    for _, row in data.iterrows():
        tokens = okt.nouns(row['title']) + okt.nouns(row['content'])
        filtered_tokens = [word for word in tokens if word not in stop_words and word not in remove_words]
        all_keywords.extend(filtered_tokens)

        # 연도별 키워드 추출
        trend_data.append({'year': row['pubDate'].year, 'keywords': filtered_tokens})

# 워드 클라우드 생성
print("Generating Word Cloud...")

# 폰트 경로 설정
font_path = "/usr/share/fonts/truetype/nanum/NanumGothic.ttf"  # 한글 폰트 파일 경로

word_counts = Counter(all_keywords)
wordcloud = WordCloud(font_path=font_path, background_color="white", width=800, height=400)
wordcloud.generate_from_frequencies(word_counts)

plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of All Keywords')
plt.show()

# 키워드 간 상관관계 분석 (빈도 기반)
print("Keyword Correlation Analysis...")
from itertools import combinations
from collections import defaultdict

# 키워드 상관관계 저장
correlation = defaultdict(Counter)

for item in trend_data:
    keywords = item['keywords']
    for pair in combinations(keywords, 2):
        correlation[pair[0]][pair[1]] += 1

# 상관관계 데이터프레임 생성
correlation_df = pd.DataFrame.from_dict(correlation, orient='index').fillna(0)

print("Analysis Complete.")
# Out:
# Processing: 전처리된__daumnews_미숙아 연하곤란.csv
# Processing: 전처리된__daumnews_미숙아 삼킴 문제.csv
# Processing: 전처리된__daumnews_미숙아 빨기 문제.csv
# Processing: 전처리된__daumnews_미숙아 모유수유 문제.csv
# Processing: 전처리된__daumnews_미숙아 수유 어려움.csv
# Generating Word Cloud...
# Keyword Correlation Analysis...
# Analysis Complete.

# %% [markdown]
# - 연도별 키워드 분석

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
from konlpy.tag import Okt
import os
from bs4 import BeautifulSoup

# 키워드 리스트 정의
essential_keywords = ["모유수유","삼킴","연하 곤란","장애", "문제", "빨기", "수유", "구강","빠는 힘"]

stop_words = [
    '가', '과', '지', '합니다', '이다', '하는', '하는것', '한', '그', '이', '를', '에', '에서', '와',
    '의', '는', '들', '도', '으로', '것', '수', '있다', '되다', '들', '및', '가', '고', '적', '더', '잘','기','달',
    '게', '등을', '라는', '하다가', '하면','내','이충','명','거','진','수가','계','또','재','안','번','세','일','며',
    '건','전','철','팀','때','말','최','딸','초','날','비','시','주','로','정','등','곳','뒤','후','제','김','원','정',
    '두','해','거의','양','개','차','증','걸','앞','세'',중','생','라며','나','점','알','훈','무','왜','저','실','줄',
    '남','병','율','살','속','애','첫','중','씨','면서','데','몇'
]

remove_words = [
    '접종','교수','통해','이후','임산부','진료','이상','약','모두','입원','지난','보고','청소년','때문','어려움','산모',
    '사진','진단','여러','문제','의사','간호사','사회','모든','은행','관리','가지','보험','당시','발생','설명','국내','미국',
    '건강','상황','입양','증가','음식','사랑','세계','시작','미숙아','아이','아기','위해','서비스','산부인과','조산','다른','처음',
    '아산병원','건우','가치','한국','정부','대해','상태','운영','위험','형사','미만','영향','원인','감소','기자','얘기','출생','태아',
    '학회','제공','집중','권장','직후','둥이','출산''분만','일반','최선','사망','거의','기간','부부','효과','동안','미국','포함',
    '사람','서울','관련','예방','모습','기적','현재','경희대','뉴스','방문','사용','최근','먹이','이야기','계속','신생아','의료','병원',
    '치료','소아','출산','엄마','퇴원','경우','가장','생각','키스','시기','예방접종','중앙대','지름','정도','매일','확인','진행','중환자실',
    '퇴원','대한','생명','민서','미군','기준','쌍둥이','제대로','시술','수도','보호자','금지','하나','초기','관찰','아빠','이제','세상','시행',
    '백신','선생님','정상','자궁','전달','김진규','응급','여성','자세','하루','정보','신후','임신','환자','또한','분만','우리','몸','지금',
    '약물','볼','시스템','가슴','결핍','김애란','사업','마음','인간','유아','베이비','강동','콜','의정부','지역','증상','임신부','질환',
    '설립','생후','수술','수빈','면역','확진','약시','기증','감염','보험금','기병','코로나','열','수사','그때','예찬','감기','조사원','못','백일해',
    '사건','둘째','바이러스'
    ]

# 파일 경로 설정
folder_path = "/content/drive/MyDrive/daum_news/pre_daum_news"  # CSV 파일들이 저장된 폴더 경로
csv_files = [f for f in os.listdir(folder_path) if f.endswith('.csv')]

# 형태소 분석기 준비
okt = Okt()

# 연도별 키워드 저장용
yearly_keywords = {}

# 각 파일 처리
for file in csv_files:
    file_path = os.path.join(folder_path, file)
    print(f"Processing: {file}")

    # 파일 불러오기
    try:
        data = pd.read_csv(file_path, encoding='utf-8')
    except UnicodeDecodeError:
        data = pd.read_csv(file_path, encoding='euc-kr')

    # 날짜 변환
    data['pubDate'] = pd.to_datetime(data['pubDate'], errors='coerce')

    # 결측치 제거
    data = data.dropna(subset=['title', 'content', 'pubDate'])

    # HTML 태그 제거
    data['title'] = data['title'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())
    data['content'] = data['content'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())

    # 연도별 키워드 추출 및 저장
    for _, row in data.iterrows():
        year = row['pubDate'].year
        tokens = okt.nouns(row['title']) + okt.nouns(row['content'])
        filtered_tokens = [word for word in tokens if word not in stop_words and word not in remove_words]

        if year not in yearly_keywords:
            yearly_keywords[year] = []
        yearly_keywords[year].extend(filtered_tokens)

# 연도별 키워드 빈도 분석
print("Analyzing yearly keyword trends...")
yearly_keyword_counts = {}

for year, keywords in yearly_keywords.items():
    yearly_keyword_counts[year] = Counter(keywords).most_common(10)  # 상위 10개 키워드

# 연도별 트렌드 시각화
for year, keyword_counts in sorted(yearly_keyword_counts.items()):
    keywords, counts = zip(*keyword_counts)

    plt.figure(figsize=(10, 5))
    plt.bar(keywords, counts)
    plt.title(f"Top Keywords in {year}")
    plt.xlabel("Keywords")
    plt.ylabel("Frequency")
    plt.xticks(rotation=45)
    plt.show()

print("Yearly trend analysis complete.")
# Out:
# Processing: 전처리된__daumnews_미숙아 연하곤란.csv
# Processing: 전처리된__daumnews_미숙아 삼킴 문제.csv
# Processing: 전처리된__daumnews_미숙아 빨기 문제.csv
# Processing: 전처리된__daumnews_미숙아 모유수유 문제.csv
# Processing: 전처리된__daumnews_미숙아 수유 어려움.csv
# Analyzing yearly keyword trends...
# Yearly trend analysis complete.

# %% [markdown]
# # Top_50 keywords & word cloud

# %%
# 필요한 라이브러리 임포트
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
from wordcloud import WordCloud
from konlpy.tag import Okt
import os
from bs4 import BeautifulSoup

# 키워드 리스트 정의
essential_keywords = ["모유수유","삼킴","연하 곤란","장애", "문제", "빨기", "수유", "구강","빠는 힘"]

stop_words = [
    '가', '과', '지', '합니다', '이다', '하는', '하는것', '한', '그', '이', '를', '에', '에서', '와',
    '의', '는', '들', '도', '으로', '것', '수', '있다', '되다', '들', '및', '가', '고', '적', '더', '잘','기','달',
    '게', '등을', '라는', '하다가', '하면','내','이충','명','거','진','수가','계','또','재','안','번','세','일','며',
    '건','전','철','팀','때','말','최','딸','초','날','비','시','주','로','정','등','곳','뒤','후','제','김','원','정',
    '두','해','거의','양','개','차','증','걸','앞','세'',중','생','라며','나','점','알','훈','무','왜','저','실','줄',
    '남','병','율','살','속','애','첫','중','씨','면서','데','몇','꼭','거나','를','은','률'
]

remove_words = [
    '접종','교수','통해','이후','임산부','진료','이상','약','모두','입원','지난','보고','청소년','때문','어려움','산모',
    '사진','진단','여러','문제','의사','간호사','사회','모든','은행','관리','가지','보험','당시','발생','설명','국내','미국',
    '건강','상황','입양','증가','음식','사랑','세계','시작','미숙아','아이','아기','위해','서비스','산부인과','조산','다른','처음',
    '아산병원','건우','가치','한국','정부','대해','상태','운영','위험','형사','미만','영향','원인','감소','기자','얘기','출생','태아',
    '학회','제공','집중','권장','직후','둥이','출산''분만','일반','최선','사망','거의','기간','부부','효과','동안','미국','포함',
    '사람','서울','관련','예방','모습','기적','현재','경희대','뉴스','방문','사용','최근','먹이','이야기','계속','신생아','의료','병원',
    '치료','소아','출산','엄마','퇴원','경우','가장','생각','키스','시기','예방접종','중앙대','지름','정도','매일','확인','진행','중환자실',
    '퇴원','대한','생명','민서','미군','기준','쌍둥이','제대로','시술','수도','보호자','금지','하나','초기','관찰','아빠','이제','세상','시행',
    '백신','선생님','정상','자궁','전달','김진규','응급','여성','자세','하루','정보','신후','임신','환자','또한','분만','우리','몸','지금',
    '약물','볼','시스템','가슴','결핍','김애란','사업','마음','인간','유아','베이비','강동','콜','의정부','지역','증상','임신부','질환',
    '설립','생후','수술','수빈','면역','확진','약시','기증','감염','보험금','기병','코로나','열','수사','그때','예찬','감기','조사원','못','백일해',
    '사건','둘째','도움','결과','검사','시간','전문의','과정','방법','생존','공급','출혈','의학','비율','증후군','직접','의학과','질병',
    '마취','이유','세포','바로','표현','요','체계','반응','전문가','계획','유발','통증','자신','반드시','대상','주치의','사실','포기','지속','바이러스'
    ]

# 폴더 경로 설정
folder_path = '/content/drive/MyDrive/daum_news/pre_daum_news'  # 실제 경로에 맞게 수정

# 폴더 내 파일 목록 가져오기
csv_files = [f for f in os.listdir(folder_path) if f.endswith('.csv')]

# 형태소 분석기 준비
okt = Okt()

# 키워드 저장용
all_keywords = []

# 각 파일 처리
for file in csv_files:
    file_path = os.path.join(folder_path, file)
    print(f"Processing: {file}")

    # 파일 불러오기
    try:
        data = pd.read_csv(file_path, encoding='utf-8')
    except UnicodeDecodeError:
        data = pd.read_csv(file_path, encoding='euc-kr')

    # 결측치 제거
    data = data.dropna(subset=['title', 'content'])

    # HTML 태그 제거
    data['title'] = data['title'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())
    data['content'] = data['content'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())

    # 키워드 추출
    for _, row in data.iterrows():
        tokens = okt.nouns(row['title']) + okt.nouns(row['content'])
        filtered_tokens = [
            word for word in tokens
            if word not in stop_words and word not in remove_words and word not in essential_keywords
        ]
        all_keywords.extend(filtered_tokens)

# 상위 50개 키워드 추출
word_counts = Counter(all_keywords)
top_50_keywords = word_counts.most_common(200)

# 데이터프레임 생성
top_50_keywords_df = pd.DataFrame(top_50_keywords, columns=['Keyword', 'Frequency'])

# 워드 클라우드 생성
font_path = "/usr/share/fonts/truetype/nanum/NanumGothic.ttf"  # 한글 폰트 경로
wordcloud = WordCloud(font_path=font_path, background_color="white", width=800, height=400)
wordcloud.generate_from_frequencies(word_counts)

# 워드 클라우드 시각화
plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of All Keywords')
plt.show()

# 상위 50개 키워드 출력
print(top_50_keywords_df)

# CSV 파일로 저장
top_50_keywords_df.to_csv("top_50_keywords(daumnews).csv", index=False, encoding='utf-8-sig')
print("상위 50개 키워드 데이터가 'top_50_keywords.csv(daumnews)'로 저장되었습니다.")
# Out:
# Processing: 전처리된__daumnews_미숙아 연하곤란.csv
# Processing: 전처리된__daumnews_미숙아 삼킴 문제.csv
# Processing: 전처리된__daumnews_미숙아 빨기 문제.csv
# Processing: 전처리된__daumnews_미숙아 모유수유 문제.csv
# Processing: 전처리된__daumnews_미숙아 수유 어려움.csv
#     Keyword  Frequency
# 0        모유        595
# 1        호흡        143
# 2        분유        122
# 3        개월        120
# 4         젖        116
# ..      ...        ...
# 195      올해         19
# 196      시력         19
# 197     어머니         19
# 198      체내         19
# 199     고혈압         19
#
# [200 rows x 2 columns]
# 상위 50개 키워드 데이터가 'top_50_keywords.csv(daumnews)'로 저장되었습니다.
